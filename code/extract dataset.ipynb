# %% [markdown]
# ## Extract zip file

# %%
import os
from google.colab import drive
drive.mount('/content/drive', timeout_ms=1200000)
# Out:
# Mounted at /content/drive

# %%
# Establece el directorio donde se encuentran los archivos .txt y .jpg
directorio = '/content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/'

# Crea una lista de rutas completas de los archivos .txt en el directorio especificado
datas_path = [os.path.join(directorio, jpg_data) for jpg_data in os.listdir(directorio)]

# Inicializa un contador para llevar la cuenta de los archivos eliminados
count = 0

# Itera sobre cada ruta de archivo .txt en la lista
for data_path in datas_path:
  # Verifica si el archivo .txt está vacío
    os.remove(data_path)
    # Incrementa el contador para cada conjunto de archivos eliminados
    count += 1

# Imprime el número total de archivos eliminados, detallando tanto los archivos .jpg como los .txt
print(f'{count} jpg files were removed')
# Out:
# 6111 jpg files were removed

# %%
#!unzip '/content/drive/MyDrive/Videos/Lobo/labels.zip' -d '/content/drive/MyDrive/Videos/Lobo/'

# %%
#len(os.listdir('/content/drive/MyDrive/TFM_Xiao/Videos/Lobo/labels'))
# Out:
# 55301

# %%
#len(os.listdir('/content/drive/MyDrive/TFM_Xiao/Videos/Lobo/4,8,9,10,12,14,15'))
# Out:
# 58787

# %%
#!unzip '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo/3,6,11,13_correct.zip' -d '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo'

# %%
#!unzip '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo/4,8,9,10,12,14,15_correct.zip' -d '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo'

# %%
#!unzip '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo/3,6,11,13.zip' -d '/content/drive/MyDrive/TFM_Xiao/Videos/Lobo'

# %%
#!unzip '/content/drive/MyDrive/TFM_Xiao/Videos/Manolo/1,2,4_correct.zip' -d '/content/drive/MyDrive/TFM_Xiao/Videos/Manolo'

# %%
# !unzip '/content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset.zip' -d '/content/drive/MyDrive/TFM_Xiao/Anotaciones'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000381.jpg
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000381.json
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000381.txt
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000382.jpg
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000382.json
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000382.txt
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000383.jpg
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000383.json
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000383.txt
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000384.jpg
#   inflating: /content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/Sep_2_000384.json
# ...

# %%
drive.flush_and_unmount()

# %% [markdown]
# 25523 images in total

# %%
len([image for image in os.listdir('/content/drive/MyDrive/TFM_Xiao/Anotaciones/dataset/')])
# Out:
# 106540
