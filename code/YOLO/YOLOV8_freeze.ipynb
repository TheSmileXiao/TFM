# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 8.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
import zipfile
import os
from ultralytics          import YOLO
from google.colab         import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
ruta_archivo_zip = '/content/drive/MyDrive/TFM_Xiao/Anotaciones/yolo_dataset.zip'
ruta_destino = './'
with zipfile.ZipFile(ruta_archivo_zip, 'r') as archivo_zip:
    # Extraer el archivo deseado en la ruta de destino
    archivo_zip.extractall(ruta_destino)

# %%
# Load a model
model = YOLO('yolov8s-seg.yaml')  # build a new model from YAML
model = YOLO('yolov8s-seg.pt')  # load a pretrained model (recommended for training)
model.info()
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:00<00:00, 160MB/s]
# YOLOv8s-seg summary: 261 layers, 11821056 parameters, 0 gradients, 42.9 GFLOPs
# (261, 11821056, 0, 42.860595200000006)

# %%
# Train the model
model.train(data='/content/yolo_dataset/dataset.yaml', epochs=50, patience=10, imgsz=640, verbose=True, batch=-1, exist_ok=True, freeze=20,
      project='/content/drive/MyDrive/TFM_Xiao/Code/YOLO/save_models', name='yolo_v8_freeze/segment')
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# %reload_ext tensorboard
# %tensorboard --logdir '/content/drive/MyDrive/TFM_Xiao/Code/YOLO/save_models/yolo_v8_freeze/segment'

# %%
model = YOLO('/content/drive/MyDrive/TFM_Xiao/Code/YOLO/save_models/yolo_v8_freeze/segment/weights/best.pt')
model.info()
# Out:
# YOLOv8s-seg summary: 261 layers, 11821443 parameters, 0 gradients, 42.9 GFLOPs
# (261, 11821443, 0, 42.8627456)

# %%
# Checking the test set (change from val rute to test rute in yaml file.)
model.val(data='/content/yolo_dataset/dataset.yaml')
# Out:
# Ultralytics YOLOv8.2.10 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810947 parameters, 0 gradients, 42.6 GFLOPs
# val: Scanning /content/yolo_dataset/labels/val.cache... 13434 images, 0 backgrounds, 0 corrupt: 100%|██████████| 13434/13434 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 840/840 [03:56<00:00,  3.55it/s]
#                    all      13434      94726       0.83      0.808      0.864      0.563      0.833      0.805      0.871      0.542
# ...

# %%
import shutil
shutil.move('/content/runs/segment/val/', '/content/drive/MyDrive/TFM_Xiao/Code/YOLO/save_models/yolo_v8_freeze/segment/test/')
# Out:
# '/content/drive/MyDrive/TFM_Xiao/Code/YOLO/save_models/yolo_v8_freeze/segment/test/'

# %%
drive.flush_and_unmount()
