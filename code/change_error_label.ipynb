# %%
import os
import json
from shapely.geometry import Polygon
from typing import List, Dict

# %%
def calcular_iou(poligono1: Polygon, poligono2: Polygon, ) -> float:
    interseccion = poligono1.intersection(poligono2).area
    union = poligono1.union(poligono2).area
    return interseccion / union

def change_label(shapes: List[Dict], label_points: Polygon, label_to_change='dog', iou_threshold=0.5) -> List[Dict]:
    # Convertir puntos a polígonos de Shapely
    poligonos = [Polygon(shape['points']) for shape in shapes]
    iou_list = []
    for p in (poligonos):
        iou_list.append(calcular_iou(p, Polygon(label_points)))
    
    if iou_list:
        max_iou_index = iou_list.index(max(iou_list))
        if shapes[max_iou_index]['label'] != label_to_change and max(iou_list) > iou_threshold:
            shapes[max_iou_index]['label'] = label_to_change
            print(f"{shapes[max_iou_index]['label']} changed to {label_to_change} with {max(iou_list)}")

        return shapes[max_iou_index]['points']

# %%
# Procesar los ficheros json del directorio que empieza por starts_with
def process_json_files_in_directory(directory, start_idx, count=50):
    
    # El poligono que quiere corregir su label, coge a partir del primer json, actualiza en cada iteracion al otro label que tiene mayor iou
    points = None
    # Recorrer los ficheros
    for i in range(start_idx, start_idx+count+1):
      file_name = f'4_{i:06d}.json'
      file_path = os.path.join(directory, file_name)
      
      # Abrir el fichero y cargar los datos
      print('processing: ', file_path)
      with open(file_path, 'r', encoding='utf-8') as json_file:
        data = json.load(json_file)
        # Primera vez entrar al bucle, encontrar el poligono que quiere procesar por label
        if not points:
          try:  
            points = [shape for shape in data['shapes'] if shape['label'] == 'dog'][0]['points']
          except IndexError as e:
            print(e)
        # Si tiene ya un punto asignado, y los datos están en el atributo data
        else:              
          # Cambar el label que tiene mayor iou y devolver el poligono nuevo del label que ha cambiado
          update_points = change_label(data['shapes'], points, iou_threshold = 0.25)
          if update_points:
            points = update_points

      # Guardar el contenido modificado de nuevo en el archivo JSON
      with open(file_path, 'w', encoding='utf-8') as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=4)

# %%
directory = './Septiembre/processing'

process_json_files_in_directory(directory, start_idx=430)
# Out:
# processing:  ./Septiembre/processing\4_000430.json
# processing:  ./Septiembre/processing\4_000431.json
# processing:  ./Septiembre/processing\4_000432.json
# processing:  ./Septiembre/processing\4_000433.json
# processing:  ./Septiembre/processing\4_000434.json
# processing:  ./Septiembre/processing\4_000435.json
# processing:  ./Septiembre/processing\4_000436.json
# processing:  ./Septiembre/processing\4_000437.json
# processing:  ./Septiembre/processing\4_000438.json
# processing:  ./Septiembre/processing\4_000439.json
# processing:  ./Septiembre/processing\4_000440.json
# processing:  ./Septiembre/processing\4_000441.json
# processing:  ./Septiembre/processing\4_000442.json
# processing:  ./Septiembre/processing\4_000443.json
# processing:  ./Septiembre/processing\4_000444.json
# processing:  ./Septiembre/processing\4_000445.json
# processing:  ./Septiembre/processing\4_000446.json
# processing:  ./Septiembre/processing\4_000447.json
# processing:  ./Septiembre/processing\4_000448.json
# processing:  ./Septiembre/processing\4_000449.json
# processing:  ./Septiembre/processing\4_000450.json
# processing:  ./Septiembre/processing\4_000451.json
# dog changed to dog with 0.9915112648215415
# processing:  ./Septiembre/processing\4_000452.json
# dog changed to dog with 0.9874054246909354
# processing:  ./Septiembre/processing\4_000453.json
# dog changed to dog with 0.9798480997746982
# processing:  ./Septiembre/processing\4_000454.json
# dog changed to dog with 0.9760754175052114
# processing:  ./Septiembre/processing\4_000455.json
# dog changed to dog with 0.9608753633011217
# processing:  ./Septiembre/processing\4_000456.json
# dog changed to dog with 0.9855585680296576
# processing:  ./Septiembre/processing\4_000457.json
# dog changed to dog with 0.9981173343669536
# processing:  ./Septiembre/processing\4_000458.json
# dog changed to dog with 0.987733729818834
# processing:  ./Septiembre/processing\4_000459.json
# dog changed to dog with 0.986979140663225
# processing:  ./Septiembre/processing\4_000460.json
# dog changed to dog with 0.9904964706810205
# processing:  ./Septiembre/processing\4_000461.json
# dog changed to dog with 0.995610392691897
# processing:  ./Septiembre/processing\4_000462.json
# dog changed to dog with 0.9848009389283112
# processing:  ./Septiembre/processing\4_000463.json
# dog changed to dog with 0.9723964155747657
# processing:  ./Septiembre/processing\4_000464.json
# dog changed to dog with 0.9516938469292008
# processing:  ./Septiembre/processing\4_000465.json
# dog changed to dog with 0.9951035117613647
# processing:  ./Septiembre/processing\4_000466.json
# dog changed to dog with 0.95849170381676
# processing:  ./Septiembre/processing\4_000467.json
# dog changed to dog with 0.9617146640861968
# processing:  ./Septiembre/processing\4_000468.json
# dog changed to dog with 0.968141275516894
# processing:  ./Septiembre/processing\4_000469.json
# dog changed to dog with 0.9811315143708084
# processing:  ./Septiembre/processing\4_000470.json
# dog changed to dog with 0.9623399859451953
# processing:  ./Septiembre/processing\4_000471.json
# dog changed to dog with 0.9779452566018169
# processing:  ./Septiembre/processing\4_000472.json
# dog changed to dog with 0.9661684940317946
# processing:  ./Septiembre/processing\4_000473.json
# dog changed to dog with 0.9390877043118794
# processing:  ./Septiembre/processing\4_000474.json
# dog changed to dog with 0.9162035045888712
# processing:  ./Septiembre/processing\4_000475.json
# dog changed to dog with 0.9134013829436944
# processing:  ./Septiembre/processing\4_000476.json
# dog changed to dog with 0.8083240037542104
# processing:  ./Septiembre/processing\4_000477.json
# dog changed to dog with 0.8527210700829274
# processing:  ./Septiembre/processing\4_000478.json
# dog changed to dog with 0.8159402829413709
# processing:  ./Septiembre/processing\4_000479.json
# processing:  ./Septiembre/processing\4_000480.json
# dog changed to dog with 0.8993766299079748
