# %%
import json
import cv2
import numpy as np
import os

# Mapa de colores en BGR para las clases
label_colors = {
    "sheep": (255, 0, 0),   # Rojo
    "wolf": (0, 255, 0),  # Verde
    "person": (0, 0, 255),  # Azul
    "dog": (255, 255, 0),# Cian
}

# %%
def build_video(dir, video_path):
  # Rutas de los directorios
  image_dir = dir
  json_dir = dir
  output_dir = os.path.join(dir, 'video_labels')

  # Asegúrate de que el directorio de salida existe
  if not os.path.exists(output_dir):
      os.makedirs(output_dir)

  # Listar todos los archivos JSON
  json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]

  for json_file in json_files:
      with open(os.path.join(json_dir, json_file), 'r') as f:
          data = json.load(f)
      
      # Cargar la imagen correspondiente
      image_path = os.path.join(image_dir, data['imagePath'])
      image = cv2.imread(image_path)
      
      # Procesar cada forma (anotación)
      for shape in data['shapes']:
          label = shape['label']
          points = np.array(shape['points'], np.int32)
          color = label_colors.get(label, (255, 255, 255))  # Color blanco por defecto
          
          # Dibujar el polígono
          cv2.polylines(image, [points], isClosed=True, color=color, thickness=2)
      
      # Guardar la imagen modificada
      output_image_path = os.path.join(output_dir, os.path.basename(image_path))
      cv2.imwrite(output_image_path, image)
  
  ## Generate video
  video_codec = cv2.VideoWriter_fourcc(*'mp4v')  # Codec para el vídeo
  video_fps = 30  # FPS del vídeo
  images = [os.path.join(output_dir, img) for img in sorted(os.listdir(output_dir)) if img.endswith(".jpg")]
  # Asumiendo que todas las imágenes tienen el mismo tamaño
  frame = cv2.imread(images[0])
  height, width, layers = frame.shape
  video = cv2.VideoWriter(video_path, video_codec, video_fps, (width, height))

  for image in images:
      video.write(cv2.imread(image))

  video.release()

# %%
list_dir = ['Agosto/1-3_6-10_correct']
list_video_path = ['videos/Agosto_1-3_6-10.mp4']
for dir, video_path in zip(list_dir, list_video_path):
  build_video(dir, video_path)
# Out:
# ['Agosto/1-3_6-10_correct\\video_labels\\10_000000.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000001.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000002.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000003.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000004.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000005.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000006.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000007.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000008.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000009.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000010.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000011.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000012.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000013.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000014.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000015.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000016.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000017.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000018.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000019.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000020.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000021.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000022.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000023.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000024.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000025.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000026.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000027.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000028.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000029.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000030.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000031.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000032.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000033.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000034.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000035.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000036.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000037.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000038.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000039.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000040.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000041.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000042.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000043.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000044.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000045.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000046.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000047.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000048.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000049.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000050.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000051.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000052.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000053.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000054.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000055.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000056.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000057.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000058.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000059.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000060.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000061.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000062.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000063.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000064.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000065.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000066.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000067.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000068.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000069.jpg', 'Agosto/1-3_6-10_correct\\video_labels\\10_000070.jpg', 'Agosto/1-3_6-10_correc ...
